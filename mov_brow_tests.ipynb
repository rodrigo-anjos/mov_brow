# %%
from random import randrange
from matplotlib import pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML


#Writer = animation.writers['ffmpeg']
#writer = Writer(fps=15, metadata=dict(artist='Me'), bitrate=1800)

fig = plt.figure()
ax = plt.axes(xlim=(-20,20), ylim=(-20, 20))
line, = ax.plot([], [])

#def init():
    #line.set_data([], [])
    #return line,
xlist=[0]
ylist=[0]
def mov_brow(i):
    x=0
    y=0
   # xlist=[0]
   # ylist=[0]
    
    z=randrange(4)
    if z==0:     #anda para direita 0->direita
        xlist.append(i)
        ylist.append(0)
    if z==1:     #anda para esquerda 1-> esquerda
        xlist.append(-i)
        ylist.append(0)
    if z==2:     #anda para cima 2->cima
        ylist.append(i)
        xlist.a
    if z==3:     #anda para baixo 3->baixo
        ylist.append(-i)
    #xlist.append(x)
    #ylist.append(y)
    #line.set_data(xlist, ylist)  
    line.set_xdata(xlist)
    line.set_ydata(ylist)
    return line,

#def atualiza_linha(i,data,line):
    #line.set_data(data[..., :i])
    #return line,


#n_passos = int(input("Número de passos: "))

plt.xlabel('X')
plt.ylabel('Y')
plt.title('Movimento Browniano')

#var_mvb = mov_brow(n_passos)
anim = animation.FuncAnimation( fig, mov_brow, interval=1000, blit=True)
#plt.plot(var_mvb[0],var_mvb[1], linewidth=0.7)
HTML(anim.to_jshtml())
#anim.save('im2.mp4', writer=writer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ddbfc4b90a98> in <module>
#      53 anim = animation.FuncAnimation( fig, mov_brow, interval=1000, blit=True)
#      54 #plt.plot(var_mvb[0],var_mvb[1], linewidth=0.7)
# ---> 55 HTML(anim.to_jshtml())
#      56 #anim.save('im2.mp4', writer=writer)
#
# ~/Desktop/mov_brow/venv_brow/lib/python3.8/site-packages/matplotlib/animation.py in to_jshtml(self, fps, embed_frames, default_mode)
#    1380                                     embed_frames=embed_frames,
#    1381                                     default_mode=default_mode)
# -> 1382                 self.save(str(path), writer=writer)
#    1383                 self._html_representation = path.read_text()
#    1384
#
# ...
