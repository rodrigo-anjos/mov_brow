# %% [markdown]
# Plot de gráfico que representa o movimento Browniano 2D.

# %%
from random import randrange
from matplotlib import pyplot as plt

plt.xkcd()
x=0
y=0
i=0
xlist=[0]
ylist=[0]
for i in range(100000):
    z=randrange(4)
    if z==0:     #anda para direita 0->direita
        x=x+1
    if z==1:     #anda para esquerda 1-> esquerda
        x=x-1
    if z==2:     #anda para cima 2->cima
        y=y+1
    if z==3:     #anda para baixo 3->baixo
        y=y-1
    xlist.append(x)
    ylist.append(y)

plt.plot(xlist,ylist, linewidth=0.7)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Movimento Browniano')
plt.show()

# %%
from random import randrange
from matplotlib import pyplot as plt
from matplotlib.animation import FuncAnimation
plt.xkcd()


def func(xlist,ylist):
    x=0
    y=0
    i=0
    xlist=[0]
    ylist=[0]
    line, = ax.plot([], [], lw=3)
    for i in range(100000):
        z=randrange(4)
        if z==0:     #anda para direita 0->direita
            x=x+1
        if z==1:     #anda para esquerda 1-> esquerda
            x=x-1
        if z==2:     #anda para cima 2->cima
            y=y+1
        if z==3:     #anda para baixo 3->baixo
            y=y-1
        xlist.append(x)
        ylist.append(y)
    line.set_data(xlist, ylist)
    return line,

plt.plot(xlist,ylist, linewidth=0.7)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Movimento Browniano')

animation = FuncAnimation(fig,func,)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-b8a99561834b> in <module>
#      27     return line,
#      28
# ---> 29 plt.plot(xlist,ylist, linewidth=0.7)
#      30 plt.xlabel('X')
#      31 plt.ylabel('Y')
#
# ~/Desktop/mov_brow/venv_brow/lib/python3.8/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# ~/Desktop/mov_brow/venv_brow/lib/python3.8/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# ~/Desktop/mov_brow/venv_brow/lib/python3.8/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# ~/Desktop/mov_brow/venv_brow/lib/python3.8/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     340
#     341         if x.shape[0] != y.shape[0]:
# --> 342             raise ValueError(f"x and y must have same first dimension, but "
#     343                              f"have shapes {x.shape} and {y.shape}")
#     344         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (2001,) and (100001,)

# %%
from random import randrange
from matplotlib import pyplot

x=0
xlist=[0]

for j in range(2):
    for i in range(1000):
        z=randrange(2)
        if z==0:    
            x=x+1
        if z==1:     
            x=x-1
        xlist.append(x)
    pyplot.plot(xlist)
    xlist

        
pyplot.show()
